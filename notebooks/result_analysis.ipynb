# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
dcg_yelp_original = \
{"Acc_s": 95.75,
 "Acc_p": 66.57,
 "Acc_t": 91.07,
 "Acc_avg": 84.46,
 "PPL": 57.08
    }

dcg_yelp_few_shot_id = \
{"Acc_s": 90.82,
"Acc_p": 62.21,
"Acc_t": 85.93,
"Acc_avg": 79.65,
"PPL": 93.66
}

dcg_yelp_few_shot_comp = \
{"Acc_s": 55.15,
"Acc_p": 52.51,
"Acc_t": 60.63,
"Acc_avg": 56.10,
"PPL": 111.03
}


dcg_mixture_original = \
{"Acc_s": 72.07,
 "Acc_tc": 96.61,
"Acc_avg": 84.34,
"PPL": 68.44
}

dcg_mixture_few_shot_id = \
{"Acc_s": 71.64,
 "Acc_tc": 95.21,
"Acc_avg": 83.43,
"PPL": 57.87
}

dcg_mixture_few_shot_comp = \
{"Acc_s": 40.34,
 "Acc_tc": 83.83,
"Acc_avg": 62.09,
"PPL": 60.33
}

ctrl_yelp_original = \
{"Acc_s": 90.07,
 "Acc_p": 75.71,
 "Acc_t": 89.82,
 "Acc_avg": 85.20,
 "PPL": 84.94
    }

ctrl_yelp_few_shot_id = \
{"Acc_s": 90.05,
 "Acc_p": 76.55,
 "Acc_t": 89.73,
 "Acc_avg": 85.44,
 "PPL": 63.72
    }

ctrl_yelp_few_shot_comp = \
{"Acc_s": 81.90,
 "Acc_p": 47.54,
 "Acc_t": 62.73,
 "Acc_avg": 64.06,
 "PPL": 64.74
    }

ctrl_mixture_original = \
{"Acc_s": 76.14,
 "Acc_tc": 88.04,
 "Acc_avg": 82.09,
 "PPL": 48.11
}

ctrl_mixture_few_shot_id = \
    {"Acc_s": 68.71,
     "Acc_tc": 85.51,
     "Acc_avg": 77.11,
     "PPL": 47.79
     }
    

ctrl_mixture_few_shot_comp = \
    {"Acc_s": 61.21,
     "Acc_tc": 74.20,
     "Acc_avg": 67.71,
     "PPL": 46.31
     }
    
contrastive_prefix_yelp_original = \
{"Acc_s": 98.21,
 "Acc_p": 87.11,
 "Acc_t": 99.21,
 "Acc_avg": 94.84,
 "PPL": 139.13
    }

contrastive_prefix_yelp_few_shot_id = \
{"Acc_s": 96.09,
 "Acc_p": 78.25,
 "Acc_t": 97.82,
 "Acc_avg": 90.72,
 "PPL": 136.95
    }

contrastive_prefix_yelp_few_shot_comp = \
{"Acc_s": 60.87,
 "Acc_p": 52.94,
 "Acc_t": 61.65,
 "Acc_avg": 58.49,
 "PPL": 132.02
    }

contrastive_prefix_mixture_original = \
{"Acc_s": 75.68,
 "Acc_tc": 95.25,
 "Acc_avg": 85.47,
 "PPL": 82.73
}

contrastive_prefix_mixture_few_shot_id = \
{"Acc_s": 74.12,
 "Acc_tc": 94.11,
 "Acc_avg": 84.12,
 "PPL": 86.10
}

contrastive_prefix_mixture_few_shot_comp = \
{"Acc_s": 52.47,
 "Acc_tc": 63.40,
 "Acc_avg": 57.94,
 "PPL": 111.43
}

# %%
# write this into a dict with the keys as column names and their values as the column values
"""
Acc_s
Acc_tc
Acc_avg
PPL
52.47
63.40
57.94
111.43
"""
